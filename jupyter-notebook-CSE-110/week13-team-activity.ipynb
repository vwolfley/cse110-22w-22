# %% [markdown]
# # Week 13 Team Activity
#
# #### Areas of Shapes Revisited
#
# ## Assingment
#
# Write functions to compute and return the areas of squares, rectangles, and circles. These functions should not display the values directly, but rather should return them, so they could be used in other parts of the program.
#
# ### CORE REQUIREMENTS
# Work through these core requirements step-by-step to complete the program. Please don't skip ahead and do the whole thing at once, because others on your team may benefit from building the program up slowly.
#
# Write a function compute_area_square that accepts a single value as a parameter, and then computes the area and returns it.
#
# 01. Below the function, write code to prompt the user for the side of a square and save it into a variable, then pass this variable to the function to compute the area. Finally, get the result back from the function and display it.
#
# 02. Repeat the previous step to write and test the functions compute_area_rectangle and compute_area_circle.
#
# 03. Write a loop to ask the user what kind of shape they have, then prompt for the length of a side, or sides, or radius, and then calls the appropriate function, and displays the result. The program should continue looping until the user enters "quit" for the shape.

# %% [markdown]
# # Core Requirments

# %% [markdown]
# ### Core Requirments 1 & 2

# %%
#######
# Date: 2022-03-128
# Week 13 Team Activity
# File: week13-team-activity.py
# Author: Vern Wolfley
# Purpose: Areas of Shapes Revisited
# Core Requirements 1 & 2
#######


# Square area of computation
def get_square_area(side):
    sq_area = float(side)**2
    return sq_area

length = input("What is the length of one side of your square? ")
area = get_square_area(length)
print(f'*** The area of your square is: 5 ***')

# Rectangle area of computation
def get_rectangle_area(length, width):
    r_len = float(length)
    r_wid = float(width)
    r_area = round((r_len * r_wid), 3)
    return r_area

r_length = input("What is the length of your rectangle? ")
r_width = input("What is the width of your rectangle? ")
area_of_rectange = get_rectangle_area(r_length, r_width)
print(f'*** The area of your rectangle is: {area_of_rectange } ***')


import math

# Circle area of computation
def get_circle_area(radius):
    cir_area = round((math.pi * float(radius)**2), 3)
    return cir_area

radius = input("What is the radius of your circle? ")
area_of_circle = get_circle_area(radius)
print(f'*** The area of your circle is: {area_of_circle} ***')
# Out:
# What is the length of one side of your square? 5
# *** The area of your square is: 25.0 ***
# What is the length of your rectangle? 5
# What is the width of your rectangle? 6
# *** The area of your rectangle is: 30.0 ***
# What is the radius of your circle? 2
# *** The area of your circle is: 12.566 ***

# %% [markdown]
# ### Core Requirments 3

# %%
#######
# Date: 2022-03-128
# Week 13 Team Activity
# File: week13-team-activity.py
# Author: Vern Wolfley
# Purpose: Areas of Shapes Revisited
# Core Requirements 3
#######


# Square area of computation
def get_square_area(side):
    sq_area = float(side)**2
    return sq_area

# Rectangle area of computation
def get_rectangle_area(length, width):
    r_len = float(length)
    r_wid = float(width)
    r_area = round((r_len * r_wid), 3)
    return r_area

import math

# Circle area of computation
def get_circle_area(radius):
    cir_area = round((math.pi * float(radius)**2), 3)
    return cir_area




options = (f'''
{"*":*^80}
What kind of shape do you have:
1. Square
2. Rectangle
3. Circle
4. Quit
{"*":*^80}''')

not_valid = (f''' 
{"*":*^80}
*{"Sorry that is not a valid choice!":^78}*
{"*":*^80}''')

end = (f''' 
{"*":*^80}
*{"Thank you - Goodbye":^78}*
{"*":*^80}''')

action = None
while action != 4:
    while True:
        try:
            print(options)
            action = int(input("\nPlease enter your choice: "))

            if action == 1:
                length = input("What is the length of one side of your square? ")
                area = get_square_area(length)
                print(f'\n*** The area of your square is: {area} ***')
            elif action == 2:
                r_length = input("What is the length of your rectangle? ")
                r_width = input("What is the width of your rectangle? ")
                area_of_rectange = get_rectangle_area(r_length, r_width)
                print(f'\n*** The area of your rectangle is: {area_of_rectange } ***')
            elif action == 3:
                radius = input("What is the radius of your circle? ")
                area_of_circle = get_circle_area(radius)
                print(f'*** The area of your circle is: {area_of_circle} ***')
            elif action == 4:
                print(end)

            while action not in [1,2,3,4]:
                print(not_valid)
                break
            break
        except ValueError:
            print(not_valid)
# Out:
# ********************************************************************************
# What kind of shape do you have:
# 1. Square
# 2. Rectangle
# 3. Circle
# 4. Quit
# ********************************************************************************
#
# Please enter your choice: e
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/9m/qm6tjx5x285ccj3txdwlssd00000gn/T/ipykernel_81178/587097662.py in <module>
#      55 #         try:
#      56         print(options)
# ---> 57         action = int(input("\nPlease enter your choice: "))
#      58
#      59         if action == 1:
#
# ValueError: invalid literal for int() with base 10: 'e'

# %% [markdown]
# ## STRETCH CHALLENGE
#
# 01. Recognize that you can compute the area of a square by passing the task along to a function that computes the areas of rectangles, by giving it the side of the square twice.
#
#     Change your program so that the compute_area_square function doesn't compute the area directly, but instead calls the compute_area_rectangle to do the work. It should pass the square side length to it (twice) and then return the value that the compute_area_rectangle function computes.
#
#
# 02. Write a new function called compute_area that accepts a first parameter of shape that can be either "square" or "circle" and then a value for the length of the side or the radius depending on the context. The function should then determine the correct function to use, based on the first parameter, call it, and return the value.
#
#     Change your program to use this function for the square and circle cases and verify that it works.
#
#
# 03. Add the ability for your new compute_area function to also compute the areas for rectangles. This means that you'll have to be able to accept calls like this: compute_area("circle", 5), this: compute_area("square", 10), and this compute_area("rectangle", 7, 8).
#
#     In order to make this work correctly, you'll need to make use of a default value for the last parameter.
#
#     Change your program to use this for all three calculations and verify that it works.

# %% [markdown]
# ### Stretch Callenge 1

# %%
#######
# Date: 2022-03-128
# Week 13 Team Activity
# File: week13-team-activity.py
# Author: Vern Wolfley
# Purpose: Areas of Shapes Revisited
# Stretch Challenge 1
#######


# Square area of computation
def compute_area_square(length):
    side = float(length)
    sq_area = side * side
    return sq_area

length = input("What is the length of one side of your square? ")
area = compute_area_square(length)
print(f'*** The area of your square is: {area} ***')
# Out:
# What is the length of one side of your square? 2
# *** The area of your square is: 4.0 ***

# %% [markdown]
# ### Stretch Callenge 2

# %%
#######
# Date: 2022-03-128
# Week 13 Team Activity
# File: week13-team-activity.py
# Author: Vern Wolfley
# Purpose: Areas of Shapes Revisited
# Stretch Challenge 2
#######


def compute_area(shape, length):
    # Square area of computation
    if shape.lower() == "square":
        side = float(length)
        sq_area = side * side
        return sq_area, shape
    # Circle area of computation
    elif shape.lower() == "circle":
        import math
        cir_area = round((math.pi * float(length)**2), 3)
        return cir_area, shape

q1 = input("What shape do you want? (square/circle)  ")
q2 = input("\nWhat is your length?  ")
area, shape = compute_area(q1, q2)

print(f'\n*** The area of your {shape} is: {area} ***')
# Out:
# What shape do you want? (square/circle)  square
#
# What is your length?  5
#
# *** The area of your square is: 25.0 ***
# {5.0}

# %% [markdown]
# ### Stretch Callenge 3

# %%
#######
# Date: 2022-03-128
# Week 13 Team Activity
# File: week13-team-activity.py
# Author: Vern Wolfley
# Purpose: Areas of Shapes Revisited
# Stretch Challenge 3
#######


# Square area of computation
def get_square_area(shape, side):
    sq_area = float(side)**2
    return sq_area, shape

# Rectangle area of computation
def get_rectangle_area(shape, length, width):
    r_len = float(length)
    r_wid = float(width)
    r_area = round((r_len * r_wid), 3)
    return r_area, shape

# Circle area of computation
def get_circle_area(shape, radius):
    import math
    cir_area = round((math.pi * float(radius)**2), 3)
    return cir_area, shape

# Compute the area of square, rectangle, circle function
# Takes arguments of shape, length, width
def compute_area(shape, length, width = 0):
    # Square area of computation
    if shape.lower() == "square":
        area, shape = get_square_area(shape, length)
    # Rectangle area of computation
    elif shape.lower() == "rectangle":
        area, shape = get_rectangle_area(shape, length, width)
    # Circle area of computation
    elif shape.lower() == "circle":
        area, shape = get_circle_area(shape, radius)

    return area, shape

options = (f'''
{"*":*^80}
What kind of shape do you have:
1. Square
2. Rectangle
3. Circle
4. Quit
{"*":*^80}''')

not_valid = (f''' 
{"*":*^80}
*{"Sorry that is not a valid choice!":^78}*
{"*":*^80}''')

end = (f''' 
{"*":*^80}
*{"Thank you - Goodbye":^78}*
{"*":*^80}''')

action = None
while action != 4:
    while True:
        try:
            print(options)
            action = int(input("\nPlease enter your choice: "))
    
            if action == 1:
                length = input("What is the length of one side of your square? ")
                area, shape = compute_area("square", length)
            elif action == 2:
                length = input("What is the length of your rectangle? ")
                width = input("What is the width of your rectangle? ")
                area, shape = compute_area("rectangle", length, width)
            elif action == 3:
                radius = input("What is the radius of your circle? ")
                area, shape = compute_area("circle", radius)
            elif action == 4:
                print(end)
                break
                
            print(f'\n*** The area of your {shape} is: {area} ***') 

            while action not in [1,2,3,4]:
                print(not_valid)
                break
            break
        except ValueError:
            print(not_valid)
# Out:
# ********************************************************************************
# What kind of shape do you have:
# 1. Square
# 2. Rectangle
# 3. Circle
# 4. Quit
# ********************************************************************************
#
# Please enter your choice: 3
# What is the radius of your circle? 2
#
# *** The area of your circle is: 12.566 ***
#
# ********************************************************************************
# What kind of shape do you have:
# 1. Square
# 2. Rectangle
# 3. Circle
# 4. Quit
# ********************************************************************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/9m/qm6tjx5x285ccj3txdwlssd00000gn/T/ipykernel_84611/996280050.py in <module>
#      74         try:
#      75             print(options)
# ---> 76             action = int(input("\nPlease enter your choice: "))
# ...
