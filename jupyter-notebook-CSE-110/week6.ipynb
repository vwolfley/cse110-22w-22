# %% [markdown]
# # CSE 110 Week 6

# %% [markdown]
# ## 06 Prepare: Checkpoint
# ### Qualifying for a Loan
#
# #### Assignment
#
# Write a program to determine whether to loan money based on the following rules.
#
# First, ask for a rating from 1–10 on the following:
#
# * How large is the loan?
# * How good is your credit history?
# * How high is your income?
# * How large is your down payment?
#
# Then, you will create a boolean variable for whether you should loan the money that will be set to either True or False. Set up a series of if statements to decide if your decision to loan is "yes" or "no" according to the following rules:
#
# * First, check if the loan size is at least 5. If it is, use the following rules:
#     * If the credit history and income are both at least 7, then the decision is "yes"
#     * If either the credit history or income is at least 7, then check if the down payment is at least 5, if it is, the decision is "yes", if not, the decision is "no"
#     * Otherwise (if neither the credit history nor income is at least 7), the decision is "no"
# * Otherwise (if the loan is not 5 or greater), use these rules:
#     * If the credit is less than 4, then the decision is "no"
#     * Otherwise, check the following:
#         * If either the income or the down payment is at least 7, the decision is "yes"
#         * If both the income and the down payment are at least 4, then the answer is "yes"
#         * Otherwise, the decision is "no"
# Finally, display the decision to the user.
#
# #### Testing Procedure
# Verify that your program works correctly by following each step in this testing procedure:
#
# Test your program with these values and ensure you arrive at the decision indicated:
# 1. Loan size: 8, Credit: 7, Income: 8, Down Payment: 1, Decision: "yes"
# 2. Loan size: 5, Credit: 2, Income: 7, Down Payment: 5, Decision: "yes"
# 3. Loan size: 8, Credit: 2, Income: 8, Down Payment: 3, Decision: "no"
# 4. Loan size: 2, Credit: 4, Income: 1, Down Payment: 7, Decision: "yes"
# 5. Loan size: 4, Credit: 5, Income: 5, Down Payment: 3, Decision: "no"

# %%
# Loan determination
# loan = int(input("How large is the loan, on a scale from [1-10]?"))
# credit = int(input("How good is your credit history, on a scale from [1-10]?"))
# income = int(input("How high is your income, on a scale from [1-10]?"))
# down_payment = int(input("How large is your down payment, on a scale from [1-10]?"))

## Test 1
# loan = 8
# credit = 7
# income = 8
# down_payment = 1

## Test 2
# loan = 5
# credit = 2
# income = 7
# down_payment = 5

## Test 3
# loan = 8
# credit = 2
# income = 8
# down_payment = 3

## Test 4
# loan = 2
# credit = 4
# income = 1
# down_payment = 7

## Test 5
loan = 4
credit = 5
income = 4
down_payment = 3

# loan = [8,5,8,2]
# credit = [7,2,2,4]
# income = [8,7,8,1]
# down_payment = [1,5,3,7]

# x=0
# while x <= 3: 
#     loan[x]
#     credit[x]
#     income[x]
#     down_payment[x]
#     x = x+1



if loan >= 5:
    if credit >= 7 and income >= 7:
        approval = True
    elif credit >= 7 or income >= 7:
        if down_payment >= 5:
            approval = True
        else:
            approval = False
    else:
        approval = False
else:
    if credit < 4:
        approval = False
    elif income >= 7 or down_payment >= 7:
        approval = True
    elif income >= 4 and down_payment >= 4:
        approval = True
    else:
        approval = False
        
if approval:
    print("YES")
else:
    print("NO")
# Out:
# NO

# %%
test = [(8, 7, 8, 1),(5, 2, 7, 5),(2, 4, 1, 7),(4, 5, 5, 3)]

for i in range(len(test[0])):
    print(test[i:3])
# Out:
# [(8, 7, 8, 1), (5, 2, 7, 5), (2, 4, 1, 7)]
# [(5, 2, 7, 5), (2, 4, 1, 7)]
# [(2, 4, 1, 7)]
# []

# %%
test1 ={"loan": 8, "credit": 7, "income": 8, "down_payment": 1}

loan = test1["loan"]
print(test1["loan"])
print(loan)
# Out:
# 8
# 8

# %%
loan = [8,5,8,2]
credit = [7,2,2,4]
income = [8,7,8,1]
down_payment = [1,5,3,7]

x=0
while x <= 3: 
    print(loan[x])
    print(credit[x])
    print(income[x])
    print(down_payment[x])
    x = x+1
# Out:
# 8
# 7
# 8
# 1
# 5
# 2
# 7
# 5
# 8
# 2
# 8
# 3
# 2
# 4
# 1
# 7

# %% [markdown]
# ## 06 Prepare: Team Activity
# ### Amusement Park Rides
#
# #### Assignment
#
# #### THE SCENARIO: RIDER REQUIREMENTS
# The local amusement park has just installed a new ride. Because of its speed and extreme twists and turns, it has very strict requirements for the riders, especially as it pertains to children or other shorter riders.
#
# To help the ride attendants follow the rules, you've been asked to write an app to help them know if the riders are acceptable for the car.
#
# The basic rules are as follows:
#
# 1. No one under 36 inches may ever ride, either by themselves or with another rider.
#
# 2. Normally, two riders sit in the car together. A single rider can only ride if they are at least 18 years old and are at least 62 inches tall.
#
# 3. If there are two riders and one of them is at least 18 years old, they may ride together.
#
# #### CORE REQUIREMENTS
# 1. Prompt the user for the age and height of the first person. Then, ask whether there is a second rider, and if so, ask for their age and height.
#
# 2. Handle the case of a single rider.
#
# 3. Finish implementing the basic rules.

# %%
#####
# Date: 2022-02-07
# Week 6 Team Activity: Amusement Park Rides
# File: week6-team.py
# Author: Vern Wolfley
# Purpose: Amusement park ride guidlines
#####

yes =  ['yes', 'y']
no = ['no','n']

response_ok = "Welcome to the ride. Please be safe and have fun!"
response_no = "Sorry, you may not ride."

rider1_age = int(input("What is the AGE of the first rider?  "))
rider1_height = int(input("What is the HEIGHT of the first rider in inches?  "))

riders = input("Is there a second rider? (yes/no)").lower()

if riders in yes:
    rider2_age = int(input("What is the AGE of the second rider?  "))
    rider2_height = int(input("What is the HEIGHT of the second rider in inches?  "))
    # Rule #1 - No one under 36 inches may ever ride, either by themselves or with another rider.
    if rider1_height <= 36 or rider2_height <= 36:
        ride = False
    else:
        # Rule #3
        if rider1_age >= 18 or rider2_age >= 18:
            ride = True
        else:
            ride = False
# Single rider case
else:
    # Rule #2    
    if rider1_height >= 62 and rider1_age >= 18:
        ride = True
    else:
        ride = False



if ride:
    print(response_ok)
else:
    print(response_no)
# Out:
# What is the AGE of the first rider?  18
# What is the HEIGHT of the first rider in inches?  61
# Is there a second rider? (yes/no)n
# Sorry, you may not ride.

# %% [markdown]
# #### STRETCH CHALLENGE
# In addition to the basic rules, the amusement park has added the following. Please implement each one for the stretch challenges:
#
# 1. If there are two riders, but neither one is at least 18 years old, they may still ride as long as they are both at least 12 years old and at least 52 inches tall.
#
# 2. If a person is age 12–17, ask if that person has a golden passport. If they do, they should be treated as if they were 18 years old for the sake of all rules. (Don't forget to apply this to the single rider case.)
#
# 3. If there are two riders, but neither one is at least 18 years old, they may still ride if one rider is at least 16 years old and the other is at least 14. (Keep in mind that the first rider may be the younger of the two or they may be the older of the two.)

# %%
#####
# Date: 2022-02-07
# Week 6 Team Activity: Amusement Park Rides
# File: week6-team.py
# Author: Vern Wolfley
# Purpose: Amusement park ride guidlines
#####

yes =  ['yes', 'y']
no = ['no','n']

# response_ok = "Welcome to the ride! /n Please be safe and have fun!"
# response_no = "Sorry, you may not ride."

response_ok = (f'''
{"*":*^80}
*{"Welcome to the ride!":^78}*
*{"Please be safe and have fun!":^78}*
{"*":*^80}
''')
response_no = (f'''
{"*":*^80}
*{"Sorry, you may not ride.":^78}*
{"*":*^80}
''')

### START
rider1_age = int(input("What is the AGE of the first rider?  "))
rider1_height = int(input("What is the HEIGHT of the first rider in inches?  "))
# Golden Passport 
if rider1_age >= 12 and rider1_age <= 17:
    golden = input("Do you have a golden passport? (yes/no)  ")
    if golden in yes:
        rider1_age = 18
    else:
        rider1_age
# print(rider1_age)

riders = input("Is there a second rider? (yes/no)").lower()

if riders in yes:
    rider2_age = int(input("What is the AGE of the second rider?  "))
    rider2_height = int(input("What is the HEIGHT of the second rider in inches?  "))
    # Golden Passport 
    if rider2_age >= 12 and rider2_age <= 17:
        golden = input("Do you have a golden passport? (yes/no)  ")
        if golden in yes:
            rider2_age = 18
        else:
            rider2_age
    
    # Rule #1 - No one under 36 inches may ever ride, either by themselves or with another rider.
    if rider1_height < 36 or rider2_height < 36:
        ride = False
    else:
        # Rule #3
        if rider1_age >= 18 or rider2_age >= 18:
            ride = True
        elif rider1_age >= 12 and rider2_age >= 12:
            if rider1_height >= 52 and rider2_height >= 52:
                ride = True 
        else:
            ride = False
            
# Single rider case
else:
    # Rule #2
    if rider1_height >= 62 and rider1_age >= 18:
        ride = True
    else:
        ride = False

### END


# print(rider1_age) 
# print(rider1_height) 
if ride:
    print(response_ok)
else:
    print(response_no)
# Out:
# What is the AGE of the first rider?  12
# What is the HEIGHT of the first rider in inches?  56
# Do you have a golden passport? (yes/no)  y
# Is there a second rider? (yes/no)y
# What is the AGE of the second rider?  14
# What is the HEIGHT of the second rider in inches?  67
# Do you have a golden passport? (yes/no)  y
#
# ********************************************************************************
# *                             Welcome to the ride!                             *
# *                         Please be safe and have fun!                         *
# ********************************************************************************
