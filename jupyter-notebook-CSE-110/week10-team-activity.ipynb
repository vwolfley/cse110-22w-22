# %% [markdown]
# # Week 10 - Team Activity
#
# ## Assignment
#
# ### Core Requirements
#
# Work through these core requirements step-by-step to complete the program. Please don't skip ahead and do the whole thing at once, because others on your team may benefit from building the program up slowly.
#
# 01. Create two lists, one for the names of the bank accounts, and one for the balances.
#
# 02. Ask the user for the name of the bank account and then for it's current balance. Keep looping until the user types "quit" for the name of an account. For each one, add the name and the balance to the appropriate list.
#
# 03. Loop through the lists using an index and display the name of the account with the balance next to it.
#
# 04. Compute and display the total balance in all of the accounts and the average balance.

# %%
"""
File: week10-team-activity
Author: Vern Wolfley
Purpose: Practicing with list indexes.
Core Requirements
"""
import time

accounts = []
balances = []

account = None
balance = None

print("Enter the names and balances of bank accounts (type: quit when done)\n")
time.sleep(.5)
while account != "Quit":
    account = input("What is the name of this account? ").title()
    if account != "Quit":
        balance = float(input("What is the balance? "))
        accounts.append(account)
        balances.append(balance)
    

print("\nAccount Information:")
for i in range(len(accounts)):
    act = accounts[i]
    bal = balances[i]
    print(f"{act} - ${bal:,.2f}")
    
total = sum(balances)
avg = sum(balances)/len(balances)
    
print(f"\nTotal Balance: ${total:,.2f}")
print(f"Average Account Balance: ${avg:,.2f}")

# %% [markdown]
# ### Stretch Challenge
#
# 01. Determine which bank account has the highest balance and display the name and balance of that account.
#
# 02. Change your display so that it shows the index of the account next to the name.
#
# 03. After displaying the list, ask the user if they want to update an account. If they respond with yes, ask for the index of the account, and the new balance.
#
# 04. Change the last step into a loop, so that the user can keep updating accounts until they say no. After each update, display the new list of balances.

# %%
"""
File: week10-team-activity
Author: Vern Wolfley
Purpose: Practicing with list indexes.
Stretch Challenge
"""

accounts = []
balances = []

account = None
balance = None
ask = 'y'

print("Enter the names and balances of bank accounts (type: quit when done)")

while account != "Quit":
    account = input("What is the name of this account? ").title()
    if account != "Quit":
        balance = float(input("What is the balance? "))
        accounts.append(account)
        balances.append(balance)
    

print("\nAccount Information:")
for i in range(len(accounts)):
    act = accounts[i]
    bal = balances[i]
    print(f"{i}. {act} - ${bal:,.2f}")
    
total = sum(balances)
avg = sum(balances)/len(balances)
largest_balance = max(balances)
largest_balance_index = balances.index(largest_balance)

# print(largest_balance)
# print(largest_balance_index)
    
print(f"\nTotal Balance: ${total:,.2f}")
print(f"Average Account Balance: ${avg:,.2f}")
print(f"Highest Balance: {accounts[largest_balance_index]} - ${largest_balance:,.2f}")


while ask == "y":
    ask = input("Do you want to update an account? (y/n) ").lower()

    if ask == "y":
        account_index = int(input("What account index do you want to update? "))
        new_amount = float(input("What is the new amount? "))
    #     print(new_amount)
    #     balances.pop(account_index)
        balances[account_index] = new_amount

        print("\nAccount Information:")
        for i in range(len(accounts)):
            act = accounts[i]
            bal = balances[i]
            print(f"{i}. {act} - ${bal:,.2f}")

        total = sum(balances)
        avg = sum(balances)/len(balances)
    
print("\nAccount Information:")
for i in range(len(accounts)):
    act = accounts[i]
    bal = balances[i]
    print(f"{i}. {act} - ${bal:,.2f}")

total = sum(balances)
avg = sum(balances)/len(balances)
# Out:
# Enter the names and balances of bank accounts (type: quit when done)
# What is the name of this account? checking
# What is the balance? 190
# What is the name of this account? savings
# What is the balance? 200
# What is the name of this account? quit
#
# Account Information:
# 0. Checking - $190.00
# 1. Savings - $200.00
#
# Total Balance: $390.00
# Average Account Balance: $195.00
# Highest Balance: Savings - $200.00
# Do you want to update an account? (y/n) y
# What account index do you want to update? 0
# What is the new amount? 4000
#
# Account Information:
# 0. Checking - $4,000.00
# 1. Savings - $200.00
# Do you want to update an account? (y/n) n
#
# Account Information:
# 0. Checking - $4,000.00
# 1. Savings - $200.00
